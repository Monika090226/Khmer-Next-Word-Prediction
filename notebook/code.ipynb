# %% [markdown]
# Preprocessing steps:
# 1. Tokenization
# https://huggingface.co/khopilot/km-tokenizer-khmer
# https://pypi.org/project/khmer-nltk/
#
# 2. Removal of stop words
# https://github.com/back-kh/KSWv2-Stop-Word-Dictionary-for-Khmer-Document
#
# 3. Removal of english/numbers

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.preprocessing import train_models

train_models(
    data_path="../data/general-text.txt",
    save_dir="../model"
)
# Out:
# | 2026-03-06 20:35:47,482 | INFO | khmer-nltk | Loaded model from C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\khmernltk\word_tokenize\sklearn_crf_ner_10000.sav |
# Training complete

# %%
from khmernltk import word_tokenize

text = "សាលារាជធានីភ្នំពេញ មិនទាន់ទទួលបាន លិខិតសុំ"

tokens = word_tokenize(text)

print(tokens)
# Out:
# | 2026-03-06 14:11:27,803 | INFO | khmer-nltk | Loaded model from C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\khmernltk\word_tokenize\sklearn_crf_ner_10000.sav |
# ['សាលា', 'រាជធានី', 'ភ្នំពេញ', ' ', 'មិន', 'ទាន់', 'ទទួលបាន', ' ', 'លិខិត', 'សុំ']

# %%
from src.preprocessing import tokenize_khmer

text = "សាលារាជធានីភ្នំពេញ មិនទាន់ទទួលបាន 2024 letter test"

tokens = tokenize_khmer(text)

print(tokens)
